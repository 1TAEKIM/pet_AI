# %% [markdown]
# ## OpenCV 사용해서 U-Net 학습에 필요한 True mask 이미지 생성

# %%
import cv2
import numpy as np
import os
import tensorflow as tf

def parse_tfrecord(example):
    features = {
        'Raw_data_ID': tf.io.FixedLenFeature([], tf.string),
        'breed': tf.io.FixedLenFeature([], tf.string),
        'age': tf.io.FixedLenFeature([], tf.int64),
        'gender': tf.io.FixedLenFeature([], tf.string),
        'species': tf.io.FixedLenFeature([], tf.string),
        'lesions': tf.io.FixedLenFeature([], tf.string),
        'path': tf.io.FixedLenFeature([], tf.string),
        'img_path': tf.io.FixedLenFeature([], tf.string),
        'x_coords': tf.io.VarLenFeature(tf.int64),
        'y_coords': tf.io.VarLenFeature(tf.int64),
    }

    example = tf.io.parse_single_example(example, features)
    
    # 이미지 경로 수정
    image_path = tf.strings.join([example['img_path'], tf.constant('/'), example['Raw_data_ID']])

    print(image_path)

    # 좌표를 리스트로 변환
    x_coords = tf.sparse.to_dense(example['x_coords'], default_value=-1)  # 빈 좌표는 -1로 처리
    y_coords = tf.sparse.to_dense(example['y_coords'], default_value=-1)  # 빈 좌표는 -1로 처리
    
    # 좌표 튜플로 반환
    coords_pairs = (x_coords, y_coords)
    return image_path, example['lesions'], coords_pairs

# TFRecord 파일 불러오는 함수
def load_dataset(tfrecord_file):
    dataset = tf.data.TFRecordDataset(tfrecord_file)
    dataset = dataset.map(parse_tfrecord)
    return dataset





def create_true_mask(image_path, x_coords, y_coords, save_dir):
    # 이미지 경로를 문자열로 변환
    image_path = image_path.numpy().decode('utf-8')
    # 이미지 불러오기 (높이, 너비 정보만 사용)
    image = cv2.imread(image_path)
    height, width, _ = image.shape
    
    # 다각형 좌표를 NumPy 배열로 변환
    pts = np.array(list(zip(x_coords.numpy(), y_coords.numpy())), np.int32)
    pts = pts.reshape((-1, 1, 2))
    
    # 마스크 이미지 생성 (배경: 회색(128), 좌표 영역: 초록색(0, 255, 0))
    mask = np.full((height, width, 3), 128, dtype=np.uint8)
    cv2.fillPoly(mask, [pts], color=(0, 255, 0))
    
    # 마스크 이미지 저장
    filename = os.path.basename(image_path)
    mask_save_path = os.path.join(save_dir, f"mask_{filename}")
    cv2.imwrite(mask_save_path, mask)
    print(f"True mask 이미지가 생성되었습니다. 저장된 경로: {mask_save_path}")




tfrecord_file = './train_symptoms_tfrecords/train_symptoms_A6.tfrecord'

dataset = load_dataset(tfrecord_file)

for example in dataset:
    image_path, lesions, coords_pairs = example
    print('img_path:', image_path.numpy().decode('utf-8'))
    print("Lesion:", lesions.numpy().decode('utf-8'))

    x_coords, y_coords = coords_pairs
    print("X Coords:", x_coords.numpy())
    print("Y Coords:", y_coords.numpy())

    # 저장할 디렉토리 생성
    save_dir = './train_true_mask_images_A6'
    os.makedirs(save_dir, exist_ok=True)
    create_true_mask(image_path, x_coords, y_coords, save_dir)
# Out:
# Tensor("StringJoin:0", shape=(), dtype=string)
# img_path: ../Segmentation/train_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_28_039246.jpg
# Lesion: A6
# X Coords: [661 564 504 505 545 603 662 733 802 853 882 903 907 872 831 788 661]
# Y Coords: [150 183 261 337 406 459 475 470 460 440 417 378 319 222 183 156 150]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 85
#      83 save_dir = './train_true_mask_images_A6'
#      84 os.makedirs(save_dir, exist_ok=True)
# ---> 85 create_true_mask(image_path, x_coords, y_coords, save_dir)
#
# Cell In[11], line 50, in create_true_mask(image_path, x_coords, y_coords, save_dir)
#      48 # 이미지 불러오기 (높이, 너비 정보만 사용)
#      49 image = cv2.imread(image_path)
# ---> 50 height, width, _ = image.shape
#      52 # 다각형 좌표를 NumPy 배열로 변환
#      53 pts = np.array(list(zip(x_coords.numpy(), y_coords.numpy())), np.int32)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ## train_A4부터 오류 발생해 확인해 보니, JSON 파일에 RAW_DATA_ID가 이미지와 맞지 않는 경우 있음

# %%
import cv2
import numpy as np
import os
import tensorflow as tf

# 실패한 이미지 경로를 저장할 리스트
failed_image_paths = []

def parse_tfrecord(example):
    features = {
        'Raw_data_ID': tf.io.FixedLenFeature([], tf.string),
        'breed': tf.io.FixedLenFeature([], tf.string),
        'age': tf.io.FixedLenFeature([], tf.int64),
        'gender': tf.io.FixedLenFeature([], tf.string),
        'species': tf.io.FixedLenFeature([], tf.string),
        'lesions': tf.io.FixedLenFeature([], tf.string),
        'path': tf.io.FixedLenFeature([], tf.string),
        'img_path': tf.io.FixedLenFeature([], tf.string),
        'x_coords': tf.io.VarLenFeature(tf.int64),
        'y_coords': tf.io.VarLenFeature(tf.int64),
    }

    example = tf.io.parse_single_example(example, features)
    
    # 이미지 경로 수정
    image_path = tf.strings.join([example['img_path'], tf.constant('/'), example['Raw_data_ID']])

    print(image_path)

    # 좌표를 리스트로 변환
    x_coords = tf.sparse.to_dense(example['x_coords'], default_value=-1)  # 빈 좌표는 -1로 처리
    y_coords = tf.sparse.to_dense(example['y_coords'], default_value=-1)  # 빈 좌표는 -1로 처리
    
    # 좌표 튜플로 반환
    coords_pairs = (x_coords, y_coords)
    return image_path, example['lesions'], coords_pairs

# TFRecord 파일 불러오는 함수
def load_dataset(tfrecord_file):
    dataset = tf.data.TFRecordDataset(tfrecord_file)
    dataset = dataset.map(parse_tfrecord)
    return dataset

def create_true_mask(image_path, x_coords, y_coords, save_dir):
    global failed_image_paths
    # 이미지 경로를 문자열로 변환
    image_path = image_path.numpy().decode('utf-8')
    # 이미지 불러오기 (높이, 너비 정보만 사용)
    image = cv2.imread(image_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_path}")
        failed_image_paths.append(image_path)
        return
    
    height, width, _ = image.shape
    
    # 다각형 좌표를 NumPy 배열로 변환
    pts = np.array(list(zip(x_coords.numpy(), y_coords.numpy())), np.int32)
    pts = pts.reshape((-1, 1, 2))
    
    # 마스크 이미지 생성 (배경: 회색(128), 좌표 영역: 초록색(0, 255, 0))
    mask = np.full((height, width, 3), 128, dtype=np.uint8)
    cv2.fillPoly(mask, [pts], color=(0, 255, 0))
    
    # 마스크 이미지 저장
    filename = os.path.basename(image_path)
    mask_save_path = os.path.join(save_dir, f"mask_{filename}")
    cv2.imwrite(mask_save_path, mask)
    print(f"True mask 이미지가 생성되었습니다. 저장된 경로: {mask_save_path}")

tfrecord_file = './val_symptoms_tfrecords/val_symptoms_A6.tfrecord'

dataset = load_dataset(tfrecord_file)

for example in dataset:
    image_path, lesions, coords_pairs = example
    print('img_path:', image_path.numpy().decode('utf-8'))
    print("Lesion:", lesions.numpy().decode('utf-8'))

    x_coords, y_coords = coords_pairs
    print("X Coords:", x_coords.numpy())
    print("Y Coords:", y_coords.numpy())

    # 저장할 디렉토리 생성
    save_dir = './val_true_mask_images_A6'
    os.makedirs(save_dir, exist_ok=True)
    create_true_mask(image_path, x_coords, y_coords, save_dir)


# 실패한 이미지 경로를 텍스트 파일로 저장
failed_image_paths_file = 'failed_val_image_paths_A6.txt'
with open(failed_image_paths_file, 'w') as f:
    for path in failed_image_paths:
        f.write(f"{path}\n")

print(f"이미지 로드가 실패한 경로들이 {failed_image_paths_file} 파일에 저장되었습니다.")
# Out:
# Tensor("StringJoin:0", shape=(), dtype=string)
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496645.jpg
# Lesion: A6
# X Coords: [1609 1655 1691 1748 1754 1727 1646 1576 1525 1513 1513 1520 1609]
# Y Coords: [1061 1064 1063 1039 1025 1007 1003 1000 1015 1025 1043 1046 1061]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496645.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496646.jpg
# Lesion: A6
# X Coords: [ 950  988 1037 1064 1033  941  835  830  845  854  854  856  950]
# Y Coords: [625 608 581 524 458 430 440 496 574 595 595 596 625]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496646.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496647.jpg
# Lesion: A6
# X Coords: [467 541 577 617 625 605 548 521 502 467]
# Y Coords: [550 556 551 521 487 442 437 461 496 550]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496647.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496649.jpg
# Lesion: A6
# X Coords: [715 811 860 886 851 700 653 632 632 715]
# Y Coords: [532 557 539 496 436 386 394 440 488 532]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496649.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496653.jpg
# Lesion: A6
# X Coords: [635 679 752 787 788 733 629 605 599 635]
# Y Coords: [604 610 598 550 466 406 398 455 539 604]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496653.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496654.jpg
# Lesion: A6
# X Coords: [ 992 1040 1058 1040  953  944  992]
# Y Coords: [589 587 541 511 497 539 589]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496654.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496655.jpg
# Lesion: A6
# X Coords: [1070 1123 1190 1259 1265 1196 1096 1036 1031 1070]
# Y Coords: [614 632 617 575 517 451 449 515 536 614]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496655.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496656.jpg
# Lesion: A6
# X Coords: [1239 1300 1431 1587 1661 1691 1725 1725 1697 1557 1377 1205 1064  951
#   874  849  874  907 1239]
# Y Coords: [ 988  996 1010  980  893  724  505  381  192   74   29   23   70  182
#   368  562  681  739  988]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496656.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496657.jpg
# Lesion: A6
# X Coords: [ 999 1024 1114 1153 1140 1047  913  864  851  999]
# Y Coords: [627 628 614 544 486 454 442 492 553 627]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496657.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496658.jpg
# Lesion: A6
# X Coords: [ 964 1056 1102 1128 1109 1003  928  900  964]
# Y Coords: [570 576 563 515 466 457 477 530 570]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496658.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496659.jpg
# Lesion: A6
# X Coords: [ 698  741  846  979 1025  980  817  637  567  567  698]
# Y Coords: [921 937 953 921 815 703 630 687 820 836 921]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496659.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496660.jpg
# Lesion: A6
# X Coords: [488 576 656 685 664 485 346 315 330 488]
# Y Coords: [663 639 585 509 438 410 500 588 628 663]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496660.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496661.jpg
# Lesion: A6
# X Coords: [397 419 484 512 507 453 366 362 397]
# Y Coords: [308 327 314 262 212 205 227 259 308]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496661.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496662.jpg
# Lesion: A6
# X Coords: [1118 1173 1207 1214 1191 1131 1080 1118]
# Y Coords: [490 499 492 451 410 383 420 490]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496662.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496663.jpg
# Lesion: A6
# X Coords: [1376 1441 1589 1744 1765 1767 1726 1459 1348 1288 1376]
# Y Coords: [822 842 844 813 743 631 511 438 473 653 822]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496663.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496664.jpg
# Lesion: A6
# X Coords: [1616 1620 1640 1652 1642 1608 1508 1504 1616]
# Y Coords: [687 684 674 620 557 534 543 634 687]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496664.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496665.jpg
# Lesion: A6
# X Coords: [ 920  935 1012 1153 1198 1221 1165 1085  939  746  645  657  680  920]
# Y Coords: [975 980 991 978 925 834 614 454 375 378 498 700 813 975]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496665.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496666.jpg
# Lesion: A6
# X Coords: [1028 1063 1101 1088 1019  919  931  944 1028]
# Y Coords: [794 793 762 690 674 682 772 799 794]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496666.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496667.jpg
# Lesion: A6
# X Coords: [1325 1339 1505 1572 1565 1370 1268 1224 1325]
# Y Coords: [1031 1034 1024  927  831  772  816  884 1031]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496667.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496671.jpg
# Lesion: A6
# X Coords: [ 984 1027 1207 1271 1343 1367 1345 1251 1061  984]
# Y Coords: [687 811 876 863 811 703 598 512 527 687]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496671.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496674.jpg
# Lesion: A6
# X Coords: [1052 1047 1115 1181 1260 1320 1333 1336 1333 1275 1175 1052]
# Y Coords: [584 622 642 648 640 611 576 534 490 460 458 584]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496674.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496675.jpg
# Lesion: A6
# X Coords: [ 931  923 1047 1197 1303 1353 1353 1237 1184 1048  933  931]
# Y Coords: [510 576 615 604 523 414 327 283 280 299 366 510]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496675.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496676.jpg
# Lesion: A6
# X Coords: [348 424 497 524 563 572 511 348]
# Y Coords: [515 599 611 606 555 494 458 515]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496676.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496677.jpg
# Lesion: A6
# X Coords: [ 912  948 1057 1120 1179 1139 1027  908  811  769  912]
# Y Coords: [758 782 775 714 582 444 379 378 478 616 758]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496677.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496678.jpg
# Lesion: A6
# X Coords: [739 728 747 820 873 924 947 941 875 739]
# Y Coords: [482 526 575 591 579 543 495 444 424 482]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496678.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496681.jpg
# Lesion: A6
# X Coords: [ 797  792  852  921 1069 1107 1117 1100 1032  905  797]
# Y Coords: [550 591 638 668 670 608 542 490 450 454 550]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496681.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496682.jpg
# Lesion: A6
# X Coords: [ 845  848  912  957 1013 1039 1043  969  845]
# Y Coords: [834 883 918 927 927 900 854 831 834]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496682.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496683.jpg
# Lesion: A6
# X Coords: [551 563 635 680 728 717 667 585 551]
# Y Coords: [623 691 734 732 679 611 578 570 623]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496683.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496684.jpg
# Lesion: A6
# X Coords: [ 91 135 207 312 363 371  81  91]
# Y Coords: [526 596 603 559 462 364 324 526]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496684.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496685.jpg
# Lesion: A6
# X Coords: [ 753  816  876  951 1028 1069 1051  947  840  751  753]
# Y Coords: [ 995 1042 1048 1039  999  908  826  782  780  835  995]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496685.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496686.jpg
# Lesion: A6
# X Coords: [1083 1109 1133 1140 1139 1128 1051  967  815  721  619  592  576  579
#   643 1083]
# Y Coords: [1048 1035  979  902  824  758  662  639  612  612  647  728  814  871
#  1040 1048]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496686.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496689.jpg
# Lesion: A6
# X Coords: [ 993  935  898  890  892  924  999 1026  993]
# Y Coords: [545 570 517 436 403 389 403 451 545]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496689.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496690.jpg
# Lesion: A6
# X Coords: [1634 1457 1237 1057  988  967  990 1099 1210 1345 1460 1586 1604 1634]
# Y Coords: [711 876 885 818 615 448 347 227 203 203 263 382 542 711]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496690.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496691.jpg
# Lesion: A6
# X Coords: [1331 1227 1210 1246 1307 1354 1331]
# Y Coords: [576 576 509 485 480 526 576]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496691.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496692.jpg
# Lesion: A6
# X Coords: [1711 1558 1509 1584 1711 1763 1711]
# Y Coords: [646 656 556 503 489 558 646]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496692.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496693.jpg
# Lesion: A6
# X Coords: [1592 1607 1574 1460 1310  992  625  412  349  370  418  496  622  775
#   943 1073 1247 1358 1505 1559 1592]
# Y Coords: [ 953  847  643  472  364  304  406  565  769  905 1010 1064 1067 1061
#  1055 1052 1052 1052 1070 1064  953]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496693.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496694.jpg
# Lesion: A6
# X Coords: [272 188 144 172 237 294 310 272]
# Y Coords: [373 386 299 251 233 271 295 373]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496694.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496696.jpg
# Lesion: A6
# X Coords: [647 609 555 523 533 569 600 639 677 647]
# Y Coords: [534 546 534 505 457 424 419 425 459 534]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496696.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496697.jpg
# Lesion: A6
# X Coords: [1502 1389 1282 1266 1268 1383 1498 1530 1538 1502]
# Y Coords: [888 918 811 729 638 566 602 695 749 888]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496697.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496698.jpg
# Lesion: A6
# X Coords: [1416 1211 1163 1243 1289 1382 1408 1416]
# Y Coords: [677 701 626 540 497 497 558 677]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496698.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496700.jpg
# Lesion: A6
# X Coords: [1016  967  899  873  876  919  978 1018 1037 1048 1016]
# Y Coords: [608 623 608 575 525 484 483 504 525 568 608]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496700.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496701.jpg
# Lesion: A6
# X Coords: [829 817 638 588 567 582 616 759 782 829]
# Y Coords: [633 652 660 610 547 485 460 468 505 633]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496701.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496702.jpg
# Lesion: A6
# X Coords: [707 502 429 427 551 748 855 895 895 707]
# Y Coords: [800 782 607 516 401 345 376 585 665 800]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496702.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496703.jpg
# Lesion: A6
# X Coords: [892 746 543 454 440 502 639 843 895 949 892]
# Y Coords: [745 810 818 742 639 539 446 464 529 676 745]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496703.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496704.jpg
# Lesion: A6
# X Coords: [1473 1503 1531 1519 1468 1377 1206 1031  886  776  766  754  771 1473]
# Y Coords: [1061  987  886  791  698  604  565  578  627  748  876 1030 1063 1061]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496704.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496705.jpg
# Lesion: A6
# X Coords: [804 930 954 916 835 754 669 596 542 532 544 549 576 617 689 804]
# Y Coords: [887 835 782 691 605 526 492 465 475 567 640 720 801 860 867 887]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496705.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496706.jpg
# Lesion: A6
# X Coords: [1109 1182 1149 1142 1090 1010  931  864  847  869  896  965 1091 1109]
# Y Coords: [950 937 796 708 641 631 713 797 851 892 922 965 970 950]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496706.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496707.jpg
# Lesion: A6
# X Coords: [809 875 889 845 805 712 665 672 714 731 809]
# Y Coords: [385 442 506 573 605 567 515 421 401 371 385]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496707.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496708.jpg
# Lesion: A6
# X Coords: [477 579 626 627 567 487 420 392 385 397 414 477]
# Y Coords: [536 526 476 431 392 383 408 433 470 500 515 536]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496708.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496709.jpg
# Lesion: A6
# X Coords: [772 740 681 640 581 561 584 615 664 730 807 831 819 804 772]
# Y Coords: [647 652 650 648 618 557 491 470 461 463 475 545 602 625 647]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496709.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496711.jpg
# Lesion: A6
# X Coords: [1244 1221 1187 1145 1082  941  837  854  899  966 1050 1147 1169 1207
#  1226 1244]
# Y Coords: [603 631 670 702 718 696 610 508 473 432 406 410 427 447 492 603]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496711.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496712.jpg
# Lesion: A6
# X Coords: [ 930  945  992 1038 1075 1084 1070 1041 1022  994  967  945  908  904
#   911  930]
# Y Coords: [495 491 488 502 520 553 564 565 567 567 567 560 543 520 514 495]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496712.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496713.jpg
# Lesion: A6
# X Coords: [ 951 1060 1179 1252 1345 1307 1250 1207 1184 1135 1095 1039  976  859
#   762  704  655  636  635  649  687  720  760  794  816  951]
# Y Coords: [ 995 1018 1000  952  877  755  655  605  546  495  466  428  418  393
#   416  513  592  661  736  821  891  917  937  962  973  995]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496713.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496714.jpg
# Lesion: A6
# X Coords: [452 523 560 500 397 394 452]
# Y Coords: [688 695 608 571 610 655 688]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496714.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496715.jpg
# Lesion: A6
# X Coords: [340 542 691 742 701 433 295 152  86  92 340]
# Y Coords: [470 418 355 278 214 196 211 295 430 508 470]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496715.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496716.jpg
# Lesion: A6
# X Coords: [548 658 716 761 751 692 559 451 394 410 431 548]
# Y Coords: [364 349 347 314 260 208 188 193 233 311 338 364]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496716.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496719.jpg
# Lesion: A6
# X Coords: [974 988 991 988 965 937 922 919 928 974]
# Y Coords: [478 469 457 442 437 439 449 466 479 478]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496719.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496720.jpg
# Lesion: A6
# X Coords: [1367 1391 1421 1444 1457 1465 1463 1442 1402 1387 1369 1358 1357 1357
#  1358 1367]
# Y Coords: [676 676 667 656 644 629 616 608 607 607 616 632 640 642 644 676]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496720.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496721.jpg
# Lesion: A6
# X Coords: [1357 1378 1395 1397 1386 1358 1274 1201 1159 1109 1092 1091 1116 1171
#  1176 1357]
# Y Coords: [291 267 233 204 160 124  95  96 128 189 241 301 339 351 350 291]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496721.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496722.jpg
# Lesion: A6
# X Coords: [375 400 429 434 419 370 317 300 290 294 306 310 375]
# Y Coords: [884 871 858 850 835 829 829 837 860 882 893 893 884]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496722.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496724.jpg
# Lesion: A6
# X Coords: [1492 1578 1588 1558 1508 1445 1426 1492]
# Y Coords: [578 570 595 646 664 642 618 578]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496724.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496725.jpg
# Lesion: A6
# X Coords: [763 769 771 771 771 769 760 754 745 740 735 735 735 740 763]
# Y Coords: [315 316 322 336 345 355 358 359 356 350 346 340 333 325 315]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496725.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496726.jpg
# Lesion: A6
# X Coords: [1153 1255 1349 1297 1106  928  826  770  760  812  937 1153]
# Y Coords: [301 328 425 592 665 667 611 520 394 289 239 301]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496726.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496727.jpg
# Lesion: A6
# X Coords: [799 847 888 917 924 924 908 838 811 785 764 747 740 739 742 756 799]
# Y Coords: [635 636 611 580 556 523 487 453 449 454 477 497 528 562 594 613 635]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496727.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496728.jpg
# Lesion: A6
# X Coords: [858 907 932 919 846 770 742 751 784 810 811 811 812 812 858]
# Y Coords: [544 531 496 434 401 420 469 528 544 545 545 545 546 546 544]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496728.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496729.jpg
# Lesion: A6
# X Coords: [ 977 1005 1057 1120 1170 1213 1233 1249 1267 1279 1285 1290 1285 1274
#  1233 1179 1131 1080 1026  980  939  906  875  846  843  842  844  847
#   977]
# Y Coords: [555 563 572 575 575 564 551 531 506 488 471 449 428 417 405 394 381 372
#  367 366 364 364 371 391 427 466 486 497 555]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496729.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496730.jpg
# Lesion: A6
# X Coords: [ 985 1000 1026 1075 1143 1169 1194 1202 1182 1115 1083 1047 1009  985
#   934  900  872  839  832  818  800  812  829  842  873  909  985]
# Y Coords: [533 539 549 547 534 517 488 452 409 349 327 309 296 288 280 282 295 316
#  329 358 403 429 462 484 490 503 533]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496730.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496731.jpg
# Lesion: A6
# X Coords: [ 867  915  999 1022 1054 1093 1161 1260 1316 1292 1240 1182 1121 1070
#   996  930  901  806  778  764  732  728  733  800  867]
# Y Coords: [579 592 608 618 636 663 674 594 473 375 319 264 229 211 219 221 233 260
#  285 328 415 449 479 543 579]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496731.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496732.jpg
# Lesion: A6
# X Coords: [1086 1120 1143 1184 1223 1267 1249 1211 1169 1140 1111 1074 1023 1011
#  1001 1005 1012 1030 1086]
# Y Coords: [717 729 734 727 728 694 657 625 590 576 568 556 559 565 582 614 627 668
#  717]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496732.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496733.jpg
# Lesion: A6
# X Coords: [1192 1151 1127 1125 1127 1117 1109 1107 1109 1102 1091 1085 1087 1096
#  1115 1129 1139 1159 1175 1195 1217 1238 1253 1274 1288 1292 1294 1289
#  1277 1253 1241 1223 1213 1192]
# Y Coords: [448 457 458 459 461 469 478 480 482 493 511 529 544 560 577 586 589 596
#  596 596 596 596 589 566 542 529 509 488 473 457 448 443 443 448]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496733.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496734.jpg
# Lesion: A6
# X Coords: [834 908 952 950 904 830 816 834]
# Y Coords: [457 483 457 411 381 389 443 457]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496734.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496735.jpg
# Lesion: A6
# X Coords: [1023 1045 1056 1058 1049 1035 1015 1002 1005 1023]
# Y Coords: [566 563 554 538 523 519 524 544 559 566]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496735.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496740.jpg
# Lesion: A6
# X Coords: [1449 1486 1673 1814 1866 1880 1847 1621 1444 1449]
# Y Coords: [796 854 883 860 756 673 579 546 607 796]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496740.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496741.jpg
# Lesion: A6
# X Coords: [618 601 558 550 555 568 612 726 808 862 893 889 878 855 767 618]
# Y Coords: [545 613 719 785 813 842 862 864 814 754 671 595 548 504 461 545]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496741.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496743.jpg
# Lesion: A6
# X Coords: [1580 1624 1621 1410 1130 1176 1249 1580]
# Y Coords: [376 298 119  26 160 428 496 376]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496743.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496744.jpg
# Lesion: A6
# X Coords: [1265 1296 1323 1332 1317 1234 1230 1225 1225 1265]
# Y Coords: [540 540 542 514 479 461 476 505 517 540]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496744.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496745.jpg
# Lesion: A6
# X Coords: [389 409 451 499 514 503 487 440 410 375 389]
# Y Coords: [761 768 768 751 717 687 672 665 667 699 761]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496745.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496747.jpg
# Lesion: A6
# X Coords: [446 510 603 708 721 665 412 446]
# Y Coords: [409 466 474 395 316 217 215 409]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496747.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496748.jpg
# Lesion: A6
# X Coords: [ 877  903  959 1046 1156 1269 1370 1431 1458 1540 1603 1638 1663 1652
#  1541 1423 1363 1219 1058  978  923  920  908  904  877]
# Y Coords: [582 644 715 769 783 769 722 603 564 514 457 377 286 246 165 148 147 153
#  207 245 307 321 355 370 582]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496748.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496749.jpg
# Lesion: A6
# X Coords: [517 611 677 741 766 787 773 668 551 448 387 334 343 351 517]
# Y Coords: [764 769 752 728 699 647 559 479 482 509 556 649 735 757 764]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496749.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496752.jpg
# Lesion: A6
# X Coords: [386 399 417 457 486 507 515 511 497 467 426 391 386]
# Y Coords: [519 549 571 567 545 516 479 444 427 415 413 431 519]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496752.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496753.jpg
# Lesion: A6
# X Coords: [1136 1176 1324 1423 1477 1427 1307 1199 1119 1085 1075 1075 1136]
# Y Coords: [780 815 801 764 683 511 437 437 502 535 622 635 780]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496753.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496754.jpg
# Lesion: A6
# X Coords: [1364 1407 1445 1453 1454 1425 1397 1304 1178 1090  995  915  837  840
#   893  919 1364]
# Y Coords: [635 605 553 533 445 365 327 279 277 291 332 397 540 629 703 710 635]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496754.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496755.jpg
# Lesion: A6
# X Coords: [ 825  859  897  938  991 1038 1072 1081 1055  957  879  814  787  780
#   825]
# Y Coords: [363 413 451 469 465 424 360 293 205 125 128 159 197 229 363]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496755.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496757.jpg
# Lesion: A6
# X Coords: [ 740  878 1076 1134 1069  769  613  592  740]
# Y Coords: [576 591 521 391 274 231 368 477 576]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496757.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496758.jpg
# Lesion: A6
# X Coords: [ 733  932 1096 1051  803  695  733]
# Y Coords: [946 975 863 706 681 770 946]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496758.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496761.jpg
# Lesion: A6
# X Coords: [808 841 850 829 773 724 709 739 808]
# Y Coords: [164 148  95  64  38  35  73 134 164]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496761.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496762.jpg
# Lesion: A6
# X Coords: [145 254 379 406 373 220 152 115 112 145]
# Y Coords: [512 511 469 403 316 293 355 433 457 512]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496762.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496763.jpg
# Lesion: A6
# X Coords: [548 622 691 704 641 573 536 548]
# Y Coords: [733 735 717 687 652 650 653 733]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496763.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496764.jpg
# Lesion: A6
# X Coords: [138 231 308 368 357 193  90  27  49 138]
# Y Coords: [826 834 822 755 707 678 688 735 796 826]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496764.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496765.jpg
# Lesion: A6
# X Coords: [ 839  935 1059 1163 1127  990  845  839]
# Y Coords: [637 672 669 532 431 409 463 637]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496765.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496766.jpg
# Lesion: A6
# X Coords: [1479 1549 1697 1764 1843 1866 1832 1636 1453 1421 1479]
# Y Coords: [886 937 957 931 836 727 551 471 518 707 886]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496766.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496767.jpg
# Lesion: A6
# X Coords: [299 391 435 407 222 152 136 120 299]
# Y Coords: [509 493 454 378 316 308 345 432 509]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496767.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496769.jpg
# Lesion: A6
# X Coords: [ 983 1022 1156 1349 1421 1439 1354 1096  875  833  850  983]
# Y Coords: [ 923  973 1004  988  889  703  517  464  488  685  763  923]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496769.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496771.jpg
# Lesion: A6
# X Coords: [1172 1238 1292 1334 1336 1256 1198 1162 1141 1138 1172]
# Y Coords: [727 740 731 686 634 583 571 575 610 653 727]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496771.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496773.jpg
# Lesion: A6
# X Coords: [511 511 554 593 614 632 628 601 542 511 506 511]
# Y Coords: [596 605 629 638 626 583 536 509 505 536 569 596]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496773.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496774.jpg
# Lesion: A6
# X Coords: [1111 1190 1249 1270 1259 1169 1048 1009 1111]
# Y Coords: [662 676 652 628 580 538 542 608 662]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496774.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496775.jpg
# Lesion: A6
# X Coords: [448 491 545 568 565 484 400 376 448]
# Y Coords: [454 475 470 431 394 353 355 412 454]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496775.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496776.jpg
# Lesion: A6
# X Coords: [ 862  883 1009 1104 1143 1136  960  788  728  862]
# Y Coords: [585 588 580 559 502 444 403 426 521 585]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496776.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496777.jpg
# Lesion: A6
# X Coords: [1171 1278 1384 1428 1352 1140 1045 1047 1171]
# Y Coords: [518 530 471 387 287 291 394 466 518]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496777.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496778.jpg
# Lesion: A6
# X Coords: [ 915  957 1021 1031  992  888  915]
# Y Coords: [723 740 720 652 623 631 723]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496778.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496779.jpg
# Lesion: A6
# X Coords: [625 682 704 692 599 574 571 625]
# Y Coords: [698 697 642 579 572 596 658 698]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496779.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496780.jpg
# Lesion: A6
# X Coords: [608 647 711 763 795 785 645 509 427 385 373 398 608]
# Y Coords: [745 743 711 640 566 474 431 436 532 636 681 717 745]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496780.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496781.jpg
# Lesion: A6
# X Coords: [589 651 800 872 910 913 840 651 475 403 368 365 589]
# Y Coords: [950 950 906 802 682 573 467 447 477 602 751 816 950]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496781.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496782.jpg
# Lesion: A6
# X Coords: [1131 1189 1277 1361 1380 1245 1085 1025 1131]
# Y Coords: [740 745 738 682 585 512 535 643 740]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496782.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496783.jpg
# Lesion: A6
# X Coords: [339 456 576 577 515 371 325 339]
# Y Coords: [567 579 551 483 431 438 484 567]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496783.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496784.jpg
# Lesion: A6
# X Coords: [ 916  987 1000 1002  891  827  810  916]
# Y Coords: [455 434 406 354 335 368 420 455]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496784.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496785.jpg
# Lesion: A6
# X Coords: [ 705  862  948  995 1006  932  727  484  405  372  452  705]
# Y Coords: [711 697 647 580 484 367 330 358 442 601 685 711]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496785.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496787.jpg
# Lesion: A6
# X Coords: [1034 1107 1157 1171 1133 1066 1027 1034]
# Y Coords: [477 484 466 425 370 365 425 477]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496787.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496788.jpg
# Lesion: A6
# X Coords: [437 440 551 575 583 549 513 461 437]
# Y Coords: [316 366 374 355 318 262 251 266 316]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496788.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496789.jpg
# Lesion: A6
# X Coords: [1147 1145 1177 1255 1287 1315 1341 1147]
# Y Coords: [747 787 815 828 824 791 728 747]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496789.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496790.jpg
# Lesion: A6
# X Coords: [1092 1135 1207 1237 1243 1195 1117 1092]
# Y Coords: [816 834 830 816 787 747 748 816]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496790.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496791.jpg
# Lesion: A6
# X Coords: [1095 1101 1172 1212 1264 1297 1319 1309 1203 1095]
# Y Coords: [736 754 799 804 798 767 716 683 662 736]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496791.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496792.jpg
# Lesion: A6
# X Coords: [ 819  841 1041 1152 1208 1228 1223 1156 1017  899  819]
# Y Coords: [598 666 690 639 586 507 452 395 395 410 598]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496792.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496793.jpg
# Lesion: A6
# X Coords: [1383 1392 1432 1487 1527 1540 1508 1391 1383]
# Y Coords: [588 635 646 655 627 579 540 531 588]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496793.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496794.jpg
# Lesion: A6
# X Coords: [167 176 261 333 345 331 167]
# Y Coords: [475 579 614 590 520 434 475]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496794.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496795.jpg
# Lesion: A6
# X Coords: [395 377 385 433 596 715 788 801 775 721 653 583 395]
# Y Coords: [134 200 235 276 332 334 303 238 170 148 130 123 134]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496795.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496796.jpg
# Lesion: A6
# X Coords: [1001 1023 1049 1079 1047 1004  960  925  907  900  900  899  909 1001]
# Y Coords: [882 876 847 764 726 683 687 703 735 783 824 836 866 882]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496796.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496797.jpg
# Lesion: A6
# X Coords: [ 904  904  960 1007 1096 1141 1136 1099  904]
# Y Coords: [368 424 483 498 495 436 380 324 368]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496797.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496798.jpg
# Lesion: A6
# X Coords: [297 321 364 503 541 512 439 297]
# Y Coords: [304 404 435 406 322 256 242 304]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496798.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496799.jpg
# Lesion: A6
# X Coords: [1563 1572 1605 1683 1707 1721 1724 1684 1643 1563]
# Y Coords: [654 690 716 722 706 667 636 607 608 654]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496799.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496800.jpg
# Lesion: A6
# X Coords: [ 909  892  891  901  923 1052 1089 1108 1116 1111 1108 1096 1039  909]
# Y Coords: [270 299 343 384 414 400 378 336 286 231 194 171 158 270]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496800.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496801.jpg
# Lesion: A6
# X Coords: [675 672 677 715 783 816 840 847 823 675]
# Y Coords: [344 372 424 468 483 464 431 380 342 344]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496801.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496803.jpg
# Lesion: A6
# X Coords: [ 909  905  960 1016 1055 1049  997  909]
# Y Coords: [296 388 420 404 360 310 264 296]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496803.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496805.jpg
# Lesion: A6
# X Coords: [668 717 843 901 924 913 809 740 668]
# Y Coords: [344 418 423 391 318 246 204 203 344]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496805.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496806.jpg
# Lesion: A6
# X Coords: [1394 1290 1213 1221 1255 1332 1374 1402 1394]
# Y Coords: [886 900 851 786 753 738 757 801 886]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496806.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496807.jpg
# Lesion: A6
# X Coords: [ 971  838  784  710  657  633  618  644  720  859  930  977 1009 1029
#  1031  971]
# Y Coords: [705 748 759 751 737 690 596 528 483 440 437 444 477 593 641 705]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496807.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496808.jpg
# Lesion: A6
# X Coords: [931 867 853 862 897 932 948 931]
# Y Coords: [698 699 642 619 602 612 642 698]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496808.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496809.jpg
# Lesion: A6
# X Coords: [1275 1216 1080  925  863  883  925 1043 1109 1244 1284 1275]
# Y Coords: [782 881 888 797 753 540 462 400 392 456 591 782]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496809.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496810.jpg
# Lesion: A6
# X Coords: [767 590 546 612 701 847 767]
# Y Coords: [701 732 588 466 435 572 701]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496810.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496811.jpg
# Lesion: A6
# X Coords: [1166 1019  787  776  968 1150 1224 1166]
# Y Coords: [944 978 931 755 635 666 795 944]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496811.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496812.jpg
# Lesion: A6
# X Coords: [1112  963  781  801  906 1012 1123 1183 1112]
# Y Coords: [649 700 547 471 394 356 371 476 649]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496812.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496813.jpg
# Lesion: A6
# X Coords: [1335 1177  912  795  796  846 1009 1212 1359 1335]
# Y Coords: [684 749 754 656 548 455 389 410 505 684]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496813.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496814.jpg
# Lesion: A6
# X Coords: [1156 1025  882  871  900 1037 1122 1167 1156]
# Y Coords: [869 921 886 773 724 681 696 739 869]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496814.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496815.jpg
# Lesion: A6
# X Coords: [1367 1429 1507 1565 1591 1549 1402 1309 1202 1129 1140 1216 1265 1294
#  1367]
# Y Coords: [892 863 811 741 630 562 550 548 525 598 712 827 878 908 892]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496815.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496816.jpg
# Lesion: A6
# X Coords: [1045 1114 1220 1329 1429 1431 1262 1005  750  486  309  260  279  299
#   312  451  695  814  866 1045]
# Y Coords: [1023  902  792  665  495  267  161  141  157  190  290  482  671  897
#   996 1008  992 1041 1057 1023]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496816.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496818.jpg
# Lesion: A6
# X Coords: [1100 1140 1172 1170 1130 1051 1014 1012 1032 1040 1100]
# Y Coords: [416 410 378 338 282 290 333 357 386 393 416]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496818.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496819.jpg
# Lesion: A6
# X Coords: [ 885 1010 1119 1167 1115 1041  936  834  762  697  669  655  670  685
#   790  885]
# Y Coords: [630 592 502 357 282 223 212 236 306 386 455 500 588 647 698 630]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496819.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496820.jpg
# Lesion: A6
# X Coords: [1270 1367 1430 1461 1484 1496 1504 1457 1295 1225 1119 1084 1067 1029
#  1020 1005  991  995  990  990 1012 1044 1066 1107 1150 1215 1270]
# Y Coords: [922 866 827 756 691 582 516 463 366 346 353 378 447 521 561 591 642 721
#  767 796 825 873 895 931 938 928 922]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496820.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496821.jpg
# Lesion: A6
# X Coords: [1171 1123  981  895  778  674  618  564  543  543  562  644  802  881
#  1005 1054 1095 1192 1227 1226 1186 1179 1171]
# Y Coords: [777 800 807 815 833 828 757 656 451 321 201 125  37  28  48  89 184 362
#  475 600 714 764 777]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496821.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496823.jpg
# Lesion: A6
# X Coords: [ 780  880 1012 1012  891  794  714  677  595  555  492  437  407  406
#   441  487  535  586  780]
# Y Coords: [673 631 487 308 277 272 257 247 261 281 337 415 475 537 571 613 638 656
#  673]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496823.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496824.jpg
# Lesion: A6
# X Coords: [1096 1132 1172 1160 1102 1024 1001 1015 1096]
# Y Coords: [655 643 608 563 547 557 616 638 655]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496824.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496825.jpg
# Lesion: A6
# X Coords: [1304 1363 1397 1391 1300 1202 1175 1196 1304]
# Y Coords: [613 577 529 473 436 458 559 592 613]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496825.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496826.jpg
# Lesion: A6
# X Coords: [647 731 757 725 664 577 490 514 559 647]
# Y Coords: [641 613 595 536 475 476 560 632 643 641]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496826.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496827.jpg
# Lesion: A6
# X Coords: [1196 1253 1256 1216 1138 1106 1097 1099 1196]
# Y Coords: [736 715 656 614 590 623 692 701 736]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496827.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496828.jpg
# Lesion: A6
# X Coords: [1088 1318 1493 1600 1495 1264 1064  913  766  751  878 1088]
# Y Coords: [743 760 698 548 349 238 223 337 467 596 691 743]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496828.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496830.jpg
# Lesion: A6
# X Coords: [892 952 983 965 919 860 827 830 869 892]
# Y Coords: [565 581 642 683 702 661 604 567 553 565]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496830.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496831.jpg
# Lesion: A6
# X Coords: [1091 1116 1144 1135 1085 1058 1044 1041 1091]
# Y Coords: [461 445 417 396 386 390 406 439 461]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496831.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496832.jpg
# Lesion: A6
# X Coords: [725 759 773 752 709 700 700 704 725]
# Y Coords: [335 350 403 427 431 399 357 352 335]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496832.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496833.jpg
# Lesion: A6
# X Coords: [1147 1180 1118 1069 1066 1147]
# Y Coords: [760 829 866 829 782 760]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496833.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496834.jpg
# Lesion: A6
# X Coords: [896 934 952 934 895 863 845 835 854 896]
# Y Coords: [547 557 604 643 650 634 605 577 548 547]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496834.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496835.jpg
# Lesion: A6
# X Coords: [1031 1063 1085 1052 1015  994  992 1031]
# Y Coords: [418 440 494 521 509 481 443 418]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496835.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496838.jpg
# Lesion: A6
# X Coords: [1202 1151 1082 1033 1081 1136 1202]
# Y Coords: [679 646 649 689 730 721 679]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496838.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496839.jpg
# Lesion: A6
# X Coords: [1515 1565 1655 1793 1842 1850 1811 1792 1730 1672 1515]
# Y Coords: [883 939 965 912 858 799 726 701 681 697 883]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496839.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496840.jpg
# Lesion: A6
# X Coords: [291 281 354 455 519 594 638 651 582 515 403 291]
# Y Coords: [653 679 728 747 751 722 637 574 493 472 458 653]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_496840.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496841.jpg
# Lesion: A6
# X Coords: [ 968 1074 1163 1165 1080  922  810  968]
# Y Coords: [797 800 744 616 551 564 728 797]
# ...
# Lesion: A6
# X Coords: [1021 1085 1227 1325 1396 1459 1492 1477 1364 1111 1019 1006 1021]
# Y Coords: [924 944 963 951 915 822 621 473 356 368 631 758 924]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498581.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498582.jpg
# Lesion: A6
# X Coords: [1015 1070 1101 1117 1123 1086 1013 1015]
# Y Coords: [710 719 700 649 591 560 608 710]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498582.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498583.jpg
# Lesion: A6
# X Coords: [ 837 1012 1073 1133 1131 1056  800  603  549  510  526  837]
# Y Coords: [690 669 602 519 426 323 262 333 460 550 630 690]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498583.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498584.jpg
# Lesion: A6
# X Coords: [771 823 890 920 957 984 977 890 749 734 771]
# Y Coords: [812 838 844 835 809 767 690 644 650 735 812]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498584.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498585.jpg
# Lesion: A6
# X Coords: [1139 1297 1504 1555 1450 1031  928 1139]
# Y Coords: [684 701 679 601 482 448 560 684]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498585.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498588.jpg
# Lesion: A6
# X Coords: [1150 1361 1441 1485 1402 1117  961 1150]
# Y Coords: [710 713 669 516 420 397 570 710]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498588.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498591.jpg
# Lesion: A6
# X Coords: [ 848  915 1029 1146 1162 1133  942  832  797  848]
# Y Coords: [404 428 434 387 339 276 227 230 255 404]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498591.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498593.jpg
# Lesion: A6
# X Coords: [ 605  720  835  979 1107 1240 1259 1059  749  462  309  243  222  283
#   605]
# Y Coords: [969 995 989 970 903 828 674 499 393 367 461 521 688 807 969]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498593.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498595.jpg
# Lesion: A6
# X Coords: [443 490 570 667 707 685 541 398 403 443]
# Y Coords: [935 980 989 932 759 601 540 644 838 935]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498595.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498596.jpg
# Lesion: A6
# X Coords: [369 579 709 721 552 315 248 266 369]
# Y Coords: [522 554 508 396 271 253 400 482 522]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498596.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498597.jpg
# Lesion: A6
# X Coords: [1121 1264 1387 1505 1565 1576 1525 1409 1183  956  827  767  761  814
#   824 1121]
# Y Coords: [718 713 709 658 608 533 436 325 289 289 332 401 505 607 623 718]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498597.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498598.jpg
# Lesion: A6
# X Coords: [ 455  692  979 1070 1097 1019  884  700  433  305  203  212  278  455]
# Y Coords: [718 773 749 644 476 319 188  94  65 125 383 556 617 718]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498598.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498599.jpg
# Lesion: A6
# X Coords: [1045 1082 1172 1297 1462 1678 1798 1852 1855 1648 1369 1138 1045 1004
#  1004 1045]
# Y Coords: [ 973 1006 1046 1054 1036  998  914  781  599  464  451  472  521  623
#   737  973]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498599.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498603.jpg
# Lesion: A6
# X Coords: [ 922  964 1070 1166 1247 1295 1273 1139  970  892  871  877  922]
# Y Coords: [952 971 985 953 886 787 655 577 581 665 746 838 952]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498603.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498604.jpg
# Lesion: A6
# X Coords: [1325 1369 1411 1444 1454 1445 1397 1367 1319 1325]
# Y Coords: [403 404 392 370 344 320 308 314 326 403]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498604.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498607.jpg
# Lesion: A6
# X Coords: [707 782 830 805 664 619 662 707]
# Y Coords: [496 473 415 368 352 421 473 496]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498607.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498608.jpg
# Lesion: A6
# X Coords: [473 593 679 754 767 716 586 463 394 367 358 371 473]
# Y Coords: [347 380 371 316 233 124  67  52  83 127 218 272 347]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498608.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498609.jpg
# Lesion: A6
# X Coords: [1690 1706 1758 1819 1851 1776 1636 1557 1509 1502 1690]
# Y Coords: [786 784 743 649 554 490 490 548 665 697 786]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498609.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498611.jpg
# Lesion: A6
# X Coords: [1178 1220 1294 1383 1475 1521 1518 1476 1400 1259 1143 1092 1064 1178]
# Y Coords: [845 858 863 863 832 778 671 570 498 483 490 633 745 845]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498611.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498612.jpg
# Lesion: A6
# X Coords: [ 964 1009 1088 1128 1134 1104  979  926  909  912  964]
# Y Coords: [499 509 503 463 378 301 237 250 311 435 499]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498612.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498613.jpg
# Lesion: A6
# X Coords: [ 999  997 1036 1069 1084 1091 1093 1047  999]
# Y Coords: [722 802 818 795 754 702 643 612 722]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498613.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498614.jpg
# Lesion: A6
# X Coords: [ 745  771  908  963 1019 1068 1099 1132 1133 1128 1075 1031  883  756
#   611  561  560  745]
# Y Coords: [ 371  338  334  332  351  407  494  654  779  874  972  996 1006  992
#   892  664  616  371]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498614.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498615.jpg
# Lesion: A6
# X Coords: [623 637 713 789 809 833 835 785 623]
# Y Coords: [734 780 808 819 802 759 708 671 734]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498615.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498616.jpg
# Lesion: A6
# X Coords: [ 879  867  867  884  969 1071 1127 1165 1185 1187 1135 1003  879]
# Y Coords: [187 232 292 351 399 419 382 298 210 148  88  78 187]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498616.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498620.jpg
# Lesion: A6
# X Coords: [608 601 637 703 787 812 871 889 905 837 608]
# Y Coords: [691 754 803 827 842 842 827 776 682 632 691]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498620.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498621.jpg
# Lesion: A6
# X Coords: [237 255 299 429 513 571 564 527 480 237]
# Y Coords: [691 795 854 886 856 788 660 568 542 691]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498621.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498622.jpg
# Lesion: A6
# X Coords: [788 791 859 887 935 947 897 788]
# Y Coords: [ 82 112 152 158 126  82  43  82]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498622.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498623.jpg
# Lesion: A6
# X Coords: [1220 1228 1281 1325 1365 1359 1265 1220]
# Y Coords: [818 887 919 894 854 803 779 818]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498623.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_498624.jpg
# Lesion: A6
# X Coords: [545 540 652 727 739 728 671 536 545]
# Y Coords: [523 558 587 547 503 448 408 419 523]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_498624.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702445.jpg
# Lesion: A6
# X Coords: [   1   26  140  287  448  629  761  904 1036 1177 1306 1544 1657 1783
#  1846 1909 1906 1897 1891 1876 1855 1858 1850 1825 1786 1750 1691 1627
#  1531 1453 1430 1423 1411 1388 1318 1291 1204 1142 1070 1012  902  842
#   748  668  595  524  439  368  271  163  127   71   11    0    7    7
#     7    1]
# Y Coords: [172 173 193 197 182 178 176 226 284 319 302 251 221 197 221 304 388 509
#  563 625 688 724 766 784 805 815 824 800 772 757 779 814 872 884 923 934
#  932 935 928 919 898 865 833 806 781 724 668 638 577 514 488 458 410 339
#  298 232 193 172]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702445.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702446.jpg
# Lesion: A6
# X Coords: [  22   73  110  155  206  250  301  382  427  491  553  590  643  688
#   730  746  742  730  730  865  964 1049 1142 1210 1328 1430 1558 1706
#  1826 1885 1916 1920 1915 1889 1873 1819 1639 1364 1102  893  698  502
#   260  139   49   28   22]
# Y Coords: [ 958  970  986 1006 1028 1052 1080 1079 1060 1052 1049 1061 1067  997
#   920  850  767  707  680  664  664  668  694  685  725  772  794  802
#   838  830  634  442  281  151   98   40   62   89   92   56   28   28
#    10    1    8   11  958]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702446.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702447.jpg
# Lesion: A6
# X Coords: [1039  953  806  647  517  406  368  398  461  568  811 1027 1205 1235
#  1256 1213 1208 1039]
# Y Coords: [ 40  14   2  37 101 211 376 580 731 862 949 952 823 539 331 163 149  40]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702447.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702448.jpg
# Lesion: A6
# X Coords: [185 328 500 595 652 670 628 588 511 433 296 203 127 185]
# Y Coords: [ 21   0   1   1  46 158 296 374 445 476 469 398 249  21]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702448.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702449.jpg
# Lesion: A6
# X Coords: [ 902  912  924  934  950  964  976  994 1004 1018 1040 1048 1062 1090
#  1118 1142 1172 1180 1186 1190 1190 1192 1206 1214 1222 1222 1218 1194
#  1152 1096 1050 1018  984  958  936  908  898  896  896  896  896  902]
# Y Coords: [155 145 129 115  89  69  55  35  25  15   5   3   3   3   3   5   7   9
#   27  51  73 101 153 187 217 241 269 303 327 343 345 343 343 339 323 299
#  275 243 209 177 163 155]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702449.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702450.jpg
# Lesion: A6
# X Coords: [ 588  471  430  402  382  689  858 1127 1204 1174  926  737  694  588]
# Y Coords: [ 366  502  680  843 1059 1080 1070  923  669  454  317  254  229  366]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702450.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702451.jpg
# Lesion: A6
# X Coords: [ 463  503  701 1027 1279 1381 1365 1216 1033  745  483  284  203  203
#   270  463]
# Y Coords: [ 104   52    0   20  169  451  755  920  994 1035 1061 1019  757  431
#   263  104]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702451.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702452.jpg
# Lesion: A6
# X Coords: [391 283 246 241 295 400 573 766 830 875 886 875 861 830 786 705 626 593
#  556 512 391]
# Y Coords: [ 51 172 225 358 493 538 587 557 516 408 280 186  96  28   3   1   1   3
#    6   3  51]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702452.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702453.jpg
# Lesion: A6
# X Coords: [ 901  852  763  694  619  581  522  472  415  412  491  631  749  907
#  1020 1082 1122 1130 1145 1170 1176 1173 1171 1162 1145 1140 1134 1113
#  1051 1019 1001  973  955  952  945  928  922  918  917  917  916  916
#   916  916  916  915  901]
# Y Coords: [ 692  698  715  745  789  825  892  956 1079 1080 1080 1080 1080 1080
#  1080 1080 1080 1064 1016  974  956  942  919  892  867  846  822  809
#   786  761  746  733  725  722  715  707  704  701  701  701  700  700
#   700  700  700  700  692]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702453.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702454.jpg
# Lesion: A6
# X Coords: [ 176  242  286  332  384  430  490  540  594  648  698  748  796  852
#   910  964 1014 1070 1122 1214 1320 1374 1422 1432 1426 1384 1370 1350
#  1328 1274 1214 1162 1144 1126 1082 1034  988  932  880  824  780  732
#   696  644  592  534  480  426  370  322  262  204  166  136  104   62
#    22    8    8   10   28   42   64  108  134  176]
# Y Coords: [149 137 123 117 105  95  75  67  63  63  63  63  63  49  29  15  13  19
#   31  53 101 131 179 241 317 467 549 613 663 725 781 833 849 847 835 831
#  827 819 807 799 785 771 761 751 735 707 683 673 663 651 623 593 575 561
#  537 495 449 421 395 365 313 265 223 173 147 149]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702454.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702455.jpg
# Lesion: A6
# X Coords: [ 561  571  593  681  798  830  888  959 1012 1055 1112 1189 1242 1325
#  1392 1446 1521 1617 1703 1766 1801 1828 1814 1804 1793 1783 1768 1712
#  1697 1649 1586 1503 1455 1412 1383 1357 1334 1334 1332 1315 1302 1286
#  1320 1324 1312 1292 1292 1291 1277 1274 1294 1334 1337 1332 1315 1294
#  1291 1277 1256 1234 1223 1213 1194 1184 1175 1140 1072 1052 1024  918
#   866  762  699  637  561]
# Y Coords: [  13   76  167  310  436  464  586  678  729  764  814  901  973 1046
#  1072 1069 1067 1061 1049 1047 1019  916  890  868  855  840  828  817
#   809  812  805  814  817  828  833  837  790  765  739  707  681  628
#   595  567  555  540  540  538  522  490  467  465  459  450  436  421
#   376  305  243  192  145   74   38   11    8   11   21   19   18   26
#    24   21   28   26   13]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702455.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702456.jpg
# Lesion: A6
# X Coords: [ 713 1008 1269 1493 1545 1549 1493 1387 1242 1072  893  706  593  551
#   536  713]
# Y Coords: [ 357  212  274  613  803  948  990 1017 1031 1058 1078 1073 1026 1004
#   857  357]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702456.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702457.jpg
# Lesion: A6
# X Coords: [411 371 347 358 381 408 411]
# Y Coords: [22  1 32 68 87 67 22]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702457.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_702458.jpg
# Lesion: A6
# X Coords: [1131 1077  991  891  846  852 1010 1131]
# Y Coords: [1115 1000  975 1000 1090 1178 1215 1115]
# True mask 이미지가 생성되었습니다. 저장된 경로: ./val_true_mask_images_A6\mask_IMG_D_A6_702458.jpg
# 이미지 로드가 실패한 경로들이 failed_val_image_paths_A6.txt 파일에 저장되었습니다.

# %% [markdown]
# ## U-Net 모델 학습에 필요한 mask 이미지 재생성

# %%
import cv2
import numpy as np
import os
import tensorflow as tf

# 실패한 이미지 경로를 저장할 리스트
failed_image_paths = []

def parse_tfrecord(example):
    features = {
        'Raw_data_ID': tf.io.FixedLenFeature([], tf.string),
        'breed': tf.io.FixedLenFeature([], tf.string),
        'age': tf.io.FixedLenFeature([], tf.int64),
        'gender': tf.io.FixedLenFeature([], tf.string),
        'species': tf.io.FixedLenFeature([], tf.string),
        'lesions': tf.io.FixedLenFeature([], tf.string),
        'path': tf.io.FixedLenFeature([], tf.string),
        'img_path': tf.io.FixedLenFeature([], tf.string),
        'x_coords': tf.io.VarLenFeature(tf.int64),
        'y_coords': tf.io.VarLenFeature(tf.int64),
    }
    example = tf.io.parse_single_example(example, features)

    # 이미지 경로 수정
    image_path = tf.strings.join([example['img_path'], tf.constant('/'), example['Raw_data_ID']])

    # 좌표를 리스트로 변환
    x_coords = tf.sparse.to_dense(example['x_coords'], default_value=0)
    y_coords = tf.sparse.to_dense(example['y_coords'], default_value=0)

    # 유효한 좌표만 남기기
    valid_coords = tf.math.not_equal(x_coords, 0) & tf.math.not_equal(y_coords, 0)
    x_coords = tf.boolean_mask(x_coords, valid_coords)
    y_coords = tf.boolean_mask(y_coords, valid_coords)

    # 좌표 튜플로 반환
    coords_pairs = (x_coords, y_coords)
    return image_path, example['lesions'], coords_pairs

# TFRecord 파일 불러오는 함수
def load_dataset(tfrecord_file):
    dataset = tf.data.TFRecordDataset(tfrecord_file)
    dataset = dataset.map(parse_tfrecord)
    return dataset

def create_segmentation_mask(image_path, x_coords, y_coords, save_dir):
    global failed_image_paths

    # 이미지 경로를 문자열로 변환
    image_path = image_path.numpy().decode('utf-8')

    # 이미지 불러오기 (높이, 너비 정보만 사용)
    image = cv2.imread(image_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_path}")
        failed_image_paths.append(image_path)
        return

    height, width, _ = image.shape

    # 다각형 좌표를 NumPy 배열로 변환
    pts = np.array(list(zip(x_coords.numpy(), y_coords.numpy())), np.int32)
    pts = pts.reshape((-1, 1, 2))

    # 유효한 좌표가 있는지 확인
    if len(pts) == 0:
        print(f"유효한 좌표가 없습니다: {image_path}")
        return

    # 세그멘테이션 마스크 생성 (배경: 회색(128), 클래스 1: 초록색(0, 255, 0), 클래스 2: 파란색(255, 0, 0), 클래스 3: 빨간색(0, 0, 255))
    mask = np.full((height, width, 3), 128, dtype=np.uint8)

    # 클래스 1: 좌표값들을 연결했을 때 그 내부 영역
    cv2.fillPoly(mask, [pts], color=(0, 255, 0))

    # 클래스 2: 좌표를 선으로 연결했을 때 그 선 영역
    poly_mask = np.zeros_like(mask, dtype=np.uint8)
    cv2.polylines(poly_mask, [pts], True, (255, 0, 0), 2)
    mask[poly_mask[:, :, 0] == 255] = [255, 0, 0]

    # 클래스 3: 클래스 1과 2를 제외한 나머지 영역
    mask[np.logical_and(mask[:, :, 0] == 128, mask[:, :, 1] == 128, mask[:, :, 2] == 128)] = [0, 0, 255]

    # 마스크 이미지 저장
    filename = os.path.basename(image_path)
    mask_save_path = os.path.join(save_dir, f"mask_{filename}")
    cv2.imwrite(mask_save_path, mask)
    print(f"세그멘테이션 마스크 이미지가 생성되었습니다. 저장된 경로: {mask_save_path}")

tfrecord_file = './val_symptoms_tfrecords/val_symptoms_A6.tfrecord'
dataset = load_dataset(tfrecord_file)

for example in dataset.take(3):
    image_path, lesions, coords_pairs = example
    print('img_path:', image_path.numpy().decode('utf-8'))
    print("Lesion:", lesions.numpy().decode('utf-8'))
    x_coords, y_coords = coords_pairs
    print("X Coords:", x_coords.numpy())
    print("Y Coords:", y_coords.numpy())

    # 저장할 디렉토리 생성
    save_dir = './val_segmentation_mask_images_A6'
    os.makedirs(save_dir, exist_ok=True)

    create_segmentation_mask(image_path, x_coords, y_coords, save_dir)

# 실패한 이미지 경로를 텍스트 파일로 저장
failed_image_paths_file = 'failed_val_image_paths_A6.txt'
with open(failed_image_paths_file, 'w') as f:
    for path in failed_image_paths:
        f.write(f"{path}\n")
print(f"이미지 로드가 실패한 경로들이 {failed_image_paths_file} 파일에 저장되었습니다.")
# Out:
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496645.jpg
# Lesion: A6
# X Coords: [1609 1655 1691 1748 1754 1727 1646 1576 1525 1513 1513 1520 1609]
# Y Coords: [1061 1064 1063 1039 1025 1007 1003 1000 1015 1025 1043 1046 1061]
# 세그멘테이션 마스크 이미지가 생성되었습니다. 저장된 경로: ./val_segmentation_mask_images_A6\mask_IMG_D_A6_496645.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496646.jpg
# Lesion: A6
# X Coords: [ 950  988 1037 1064 1033  941  835  830  845  854  854  856  950]
# Y Coords: [625 608 581 524 458 430 440 496 574 595 595 596 625]
# 세그멘테이션 마스크 이미지가 생성되었습니다. 저장된 경로: ./val_segmentation_mask_images_A6\mask_IMG_D_A6_496646.jpg
# img_path: ../Segmentation/val_labelingdata/dog/skin/camera/symp/A6/IMG_D_A6_496647.jpg
# Lesion: A6
# X Coords: [467 541 577 617 625 605 548 521 502 467]
# Y Coords: [550 556 551 521 487 442 437 461 496 550]
# 세그멘테이션 마스크 이미지가 생성되었습니다. 저장된 경로: ./val_segmentation_mask_images_A6\mask_IMG_D_A6_496647.jpg
# 이미지 로드가 실패한 경로들이 failed_val_image_paths_A6.txt 파일에 저장되었습니다.
